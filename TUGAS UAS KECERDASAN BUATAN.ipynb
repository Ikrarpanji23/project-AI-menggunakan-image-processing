# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
from skimage import data,filters
image = data.coins()
edges = filters.sobel(image)
plt.imshow(edges, cmap='gray')
import numpy as np
from skimage import data
import numpy as np
from skimage import data,filters
import matplotlib.pyplot as plt 
# %matplotlib inline
from PIL import Image, ImageFilter
from PIL import ImageEnhance

# %%
im = Image.open( 'Inter.jpg' )
plt.imshow(im)

# %%
edges = filters.sobel(im)
plt.imshow(edges, cmap='gray')

# %%
enh = ImageEnhance.Contrast(im)
enh.enhance(1.8)
# Out:
# <PIL.Image.Image image mode=RGB size=710x449 at 0x256830ACE80>

# %%
mask = im < 87
im[mask]=255
plt.imshow(im, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3b4c8593aa2d> in <module>
# ----> 1 mask = im < 87
#       2 im[mask]=255
#       3 plt.imshow(im, cmap="gray")
#
# TypeError: '<' not supported between instances of 'JpegImageFile' and 'int'
